# %%
import sys
import numpy as np
import pandas as pd

# %%
print(sys.path[3])
# Out:
# M:\tnw\bn\gk\GL\Papers\2022 - Membrane with Felix and Djim\Codes\QCM-D

# %%
#Give name of the files if working from home (V:)
og_path = sys.path[3]

path4 =r"\20220223"
file41= "\hex_PIP_GTP.txt"
file42 = "\hex_PIP_no_GTP.txt"
file43 = "\hex_PS_no_GTP.txt"
file44 = "\oct_PIP2_GTP.txt"
file45= "\oct_PIP2_no_GTP.txt"
file46 = "\oct_PS_GTP.txt"
file47 = "\oct_PS_no_GTP.txt"

path5 =r"\20220224"
file51= "\hex_DOPC_GTP.txt"
file52 = "\hex_DOPC_noGTP.txt"
file53 = "\hex_PIP2_GTP.txt"
file54 = "\hex_PIP2_noGTP.txt"

path6 =r"\20220303"
file61= "\hex_GTP1.txt"
file62 = "\hex_GTP2.txt"
file63 = "\hex_GTP3old.txt"
file64 = "\hex_GTPnew1.txt"
file65= "\hex_GTPnew2.txt"
file66 = "\hex_noGTP1.txt"
file67 = "\hex_noGTP2.txt"

path7 = r"\20220310"
file71= "\PIP_hex_GTP_1.txt"
file72 = "\PIP_hex_GTP_2.txt"
file73 = "\PIP_hex_GTP_nospin_1.txt"
file74 = "\PIP_hex_GTP_nospin_2.txt"
file75= "\PIP_hex_noGTP_1.txt"
file76 = "\PIP_hex_noGTP_2.txt"
file77 = "\PIP_hex_noGTP_nospin.txt"

path8= r"\20220316-17_mix"
file81= r"\20220316_mix_50nMhex_freshGTP.txt"
file82= r"\20220316_mix_50nMhex_freshGTP2.txt"
file83= r"\20220316_mix_50nMhex_noGTP.txt"
#####
file84= r"\20220317_mix_50nMhex_GTP.txt"
file85= r"\20220317_mix_50nMhex_GTP2.txt"
file86= r"\20220317_mix_50nMhex_noGTP.txt"
file87= r"\20220317_mix_50nMhex_noGTP2.txt"
####
file88= r"\20220317_mix_50nMhex_GTP3.txt"
file89= r"\20220317_mix_50nMhex_GTP4.txt"
file810= r"\20220317_mix_50nMhex_noGTP3.txt"
file811= r"\20220317_mix_50nMhex_noGTP4_wierd.txt"

path15= r"\20220531\\"
file151 = "20220531_1_PC.txt" #hex, no GTP all
file152 = "20220531_2_PC.txt" 
file153 = "20220531_3_20%PS.txt" 
file154 = "20220531_4_20%PS.txt" 
file155 = "20220531_5_mix.txt" #hex, no GTP all
file156 = "20220531_6_mix.txt" 
file157 = "20220531_7_noSLB.txt" 
file158 = "20220531_8_noSLB.txt" 

path16= r"\20220602\\"
file161 = "1_ch1_octnew_GTP.txt" 
file162 = "1_ch2_octold_GTP.txt" 
file163 = "1_ch3_octnew_GTP.txt" 
file164 = "1_ch4_hex_GTP.txt" 
file165 = "2_ch1_octold_GTP.txt"
file166 = "2_ch2_octold_noGTP.txt" 
file167 = "2_ch3_octnew_GTP.txt" 
file168 = "2_ch4_octnew_noGTP.txt" 

path17= r"\20220603\\"
file171 = "1_ch1_noSLB_GTP.txt" 
file172 = "1_ch2_noSLB_GTP.txt" 
file173 = "1_ch3_noSLB_GTP.txt" 
file174 = "1_ch4_noSLB_noGTP.txt" 
file175 = "2_ch1_octnew_GTP.txt"
file176 = "2_ch2_octnew_noGTP.txt" 
file177 = "2_ch3_octold_GTP.txt" 
file178 = "2_ch4_octold_noGTP.txt" 
file179 = "3_ch1_octnew_GTP.txt"
file1710 = "3_ch2_octnew_noGTP.txt" 
file1711 = "3_ch3_octold_GTP.txt" 
file1712 = "3_ch4_octold_noGTP.txt" 

path18= r"\20220609\\"
file181 = "1_ch1_PS_oct_GTP.txt" 
file182 = "1_ch2_PS_oct_GTP.txt" 
file183 = "1_ch3_PS_hex_GTP.txt" 
file184 = "1_ch4_PS_hex_GTP.txt"

path19= r"\20220621/"
file191 = "1_ch1_PC_hex_GTP.txt" 
file192 = "1_ch2_PC_hex_GTP.txt" 
file193 = "1_ch3_PC_hex_GTP.txt" 
file194 = "1_ch4_PS_hex_GTP.txt" 
file195 = "2_ch1_PIP2_oct_GTP.txt"
file196 = "2_ch2_PIP2_oct_GTP.txt" 
file197 = "2_ch3_PIP2_oct_noGTP.txt" 
file198 = "2_ch4_pip2_oct_noGTP.txt"

path20= r"\20220713\\"
file201 = "1_ch1_PS_oct_noGTP.txt" 
file202 = "1_ch2_PS_oct_noGTP.txt" 
file203 = "1_ch3_PS_oct_noGTP.txt" 
file204 = "1_ch4_PS_oct_GTP.txt" 
file205 = "2_ch1_PC_oct_GTP.txt"
file206 = "2_ch2_PC_oct_GTP.txt" 
file207 = "2_ch3_PC_oct_noGTP.txt" 
file208 = "2_ch4_PC_oct_noGTP.txt"

path21= r"\20220712\\"
file211 = "1_ch1_PIP2_oct_GTP.txt" 
file212 = "1_ch2_PIP2_oct_GTP.txt" 
file213 = "1_ch3_PIP2_oct_GTP.txt"

#Function to find in an array the nearset value to a given value. I use it to find the time value closest to a specific time. 
def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return array[idx]

#define function to get the interesting values (max value just before septin buffer is added, 
#and final values after SB is added)
def end_result(inp, duration, mode):
    start = inp[(inp.index>=0)&(inp.index<=2/6)].mean(axis=0)
    end = inp[(inp.index>=duration-(2/6))&(inp.index<=duration)].mean(axis=0)
    depol = inp[(inp.index>=inp.index[-1]-(2/6))].mean(axis=0)
    if mode == "max":
        result = end-start
    elif mode == "after":
        result = depol-start
    return (result)

# %%
# Defibe config file:
    #Time at which septins get to the sensor 
    #Date
    #Lipid composition 
    #Oct or hex
    #Duration of septin complexes addition until septin buffer is added. 
    #Presence (+) or absence (-) of GTP. 
    #Septin concentration
    #mode --> in case any of the overtones has stopped working overtime. 
table_dict={
    
    og_path+path15+file151:[26,20220531,"DOPC", "hex", 32, "-", 50, "a"], #0
    og_path+path15+file152:[26,20220531,"DOPC", "hex", 32, "-", 50, "a"],
    og_path+path15+file153:[26,20220531,"20%PS", "hex", 32, "-", 50, "a"], 
    og_path+path15+file154:[26,20220531,"20%PS", "hex", 32, "-", 50, "a"],
    
    og_path+path15+file155:[24.5,20220531,"mix", "hex", 29, "-", 50, "a"], #4
    og_path+path15+file156:[25,20220531,"mix", "hex", 29, "-", 50, "a"],
    og_path+path15+file157:[26.5,20220531,"noSLB", "hex", 28, "-", 50, "a"], 
    og_path+path15+file158:[26.5,20220531,"noSLB", "hex", 28, "-", 50, "b"],
    
    og_path+path16+file161:[39.5,20220531,"mix", "oct", 35, "+", 17.3, "a"], #8
    og_path+path16+file162:[40,20220531,"mix", "oct", 35, "+", 50, "a"],
    og_path+path16+file163:[40,20220531,"mix", "oct", 34, "+", 17.3, "a"], 
    og_path+path16+file164:[41,20220531,"mix", "hex", 34, "+", 50, "a"],
    og_path+path16+file165:[25,20220531,"mix", "oct", 33, "+", 50, "a"], #12
    og_path+path16+file166:[25,20220531,"mix", "oct", 33, "-", 50, "a"],
    og_path+path16+file167:[27,20220531,"mix", "oct", 32, "+", 50, "a"], 
    og_path+path16+file168:[25.5,20220531,"mix", "oct", 32, "-", 50, "a"],
    
    og_path+path17+file171:[14.5,20220531,"noSLB", "hex", 32, "+", 50, "a"], #16
    og_path+path17+file172:[14.5,20220531,"noSLB", "hex", 31, "+", 50, "a"],
    og_path+path17+file173:[18,20220531,"noSLB", "hex", 28, "+", 50, "a"], 
    og_path+path17+file174:[16,20220531,"noSLB", "hex", 31, "-", 50, "a"],
    og_path+path17+file175:[29,20220531,"mix", "oct", 33.5, "+", 50, "a"], #20
    og_path+path17+file176:[29,20220531,"mix", "oct", 33.5, "-", 50, "a"],
    og_path+path17+file177:[31,20220531,"mix", "oct", 33, "+", 50, "a"], 
    og_path+path17+file178:[31,20220531,"mix", "oct", 33, "-", 50, "a"],
    og_path+path17+file179:[25.5,20220531,"mix", "oct", 31.5, "+", 50, "a"], #24
    og_path+path17+file1710:[25.5,20220531,"mix", "oct", 31.5, "-", 50, "a"],
    og_path+path17+file1711:[27.5,20220531,"mix", "oct", 31, "+", 50, "a"], 
    og_path+path17+file1712:[27,20220531,"mix", "oct", 31, "-", 50, "c"],
    
    og_path+path8+file81:[48,20220531,"mix", "hex", 42, "+", 50, "a"], #28
    og_path+path8+file82:[48,20220531,"mix", "hex", 42, "+", 50, "a"],
    og_path+path8+file83:[48,20220531,"mix", "hex", 42, "-", 50, "a"], 

    og_path+path8+file84:[33,20220531,"mix", "hex", 41, "+", 50, "a"], #31
    og_path+path8+file85:[33,20220531,"mix", "hex", 41, "+", 50, "a"], 
    og_path+path8+file86:[33,20220531,"mix", "hex", 41, "-", 50, "a"],
    og_path+path8+file87:[34,20220531,"mix", "hex", 41, "-", 50, "a"], 
    
    og_path+path8+file88:[26,20220531,"mix", "hex", 38, "+", 50, "a"], #35
    og_path+path8+file89:[27,20220531,"mix", "hex", 38, "+", 50, "a"], 
    og_path+path8+file810:[26,20220531,"mix", "hex", 38, "-", 50, "a"],
    
    og_path+path4+file41:[26+25,20220531,"pip", "hex", 40, "~", 50, "a"], #38
    og_path+path5+file53:[40,20220531,"pip", "hex", 40, "~", 50, "a"], 
    og_path+path6+file61:[38,20220531,"pip", "hex", 20, "~", 50, "a"],
    og_path+path6+file62:[38,20220531,"pip", "hex", 20, "~", 50, "a"],
    og_path+path6+file63:[25,20220531,"pip", "hex", 39, "~", 50, "a"], 
    
    og_path+path6+file64:[25,20220531,"pip", "hex", 39, "+", 50, "a"], #43
    og_path+path6+file65:[25,20220531,"pip", "hex", 39, "+", 50, "a"], 
    og_path+path7+file73:[20,20220531,"pip", "hex", 45, "+", 50, "a"],
    og_path+path7+file74:[20,20220531,"pip", "hex", 45, "+", 50, "a"],
    
    og_path+path4+file42:[45,20220531,"pip", "hex", 40, "-", 50, "a"], #47
    og_path+path5+file54:[40,20220531,"pip", "hex", 40, "-", 50, "a"], 
    og_path+path6+file66:[38,20220531,"pip", "hex", 40, "-", 50, "a"],
    og_path+path6+file67:[38,20220531,"pip", "hex", 40, "-", 50, "a"],
    og_path+path7+file77:[20,20220531,"pip", "hex", 43, "-", 50, "a"],
    
    og_path+path18+file181:[30,20220531,"20%PS", "oct", 30, "+", 50, "a"], 
    og_path+path18+file182:[30,20220531,"20%PS", "oct", 30, "+", 50, "a"], 
    og_path+path18+file183:[30,20220531,"20%PS", "hex", 30, "+", 50, "a"],
    og_path+path18+file184:[30,20220531,"20%PS", "hex", 30, "+", 50, "a"],
    og_path+path19+file194:[29,20220531,"20%PS", "hex", 30, "+", 50, "a"],
    
    og_path+path19+file191:[29,20220531,"DOPC", "hex", 30, "+", 50, "a"],
    og_path+path19+file192:[29,20220531,"DOPC", "hex", 30, "+", 50, "c"], 
    og_path+path19+file193:[29,20220531,"DOPC", "hex", 30, "+", 50, "a"],
    
    og_path+path20+file201:[24,20220531,"20%PS", "oct", 30, "-", 50, "a"], 
    og_path+path20+file202:[24,20220531,"20%PS", "oct", 30, "-", 50, "a"], 
    og_path+path20+file203:[24,20220531,"20%PS", "oct", 30, "-", 50, "a"],
    og_path+path20+file204:[24,20220531,"20%PS", "oct", 30, "+", 50, "a"],
    
    og_path+path20+file205:[25,20220531,"DOPC", "oct", 30, "+", 50, "a"], 
    og_path+path20+file206:[25,20220531,"DOPC", "oct", 30, "+", 50, "a"], 
    og_path+path20+file207:[25,20220531,"DOPC", "oct", 30, "-", 50, "a"],
    og_path+path20+file208:[25,20220531,"DOPC", "oct", 30, "-", 50, "a"],
    
    og_path+path19+file195:[24,20220531,"pip", "oct", 30, "+", 50, "a"], 
    og_path+path19+file196:[24,20220531,"pip", "oct", 30, "+", 50, "a"], 
    og_path+path19+file197:[24,20220531,"pip", "oct", 30, "-", 50, "a"],
    og_path+path19+file198:[24,20220531,"pip", "oct", 30, "-", 50, "a"],
    
    og_path+path21+file211:[24,20220531,"pip", "oct", 30, "+", 50, "a"], 
    og_path+path21+file212:[24,20220531,"pip", "oct", 30, "+", 50, "a"], 
    og_path+path21+file213:[24,20220531,"pip", "oct", 30, "+", 50, "a"]
}

# %%
#Define dataframe to store the data
table = pd.DataFrame(columns=['F7', 'D7', 'soft', 'date', 'lipids', 'septin',"GTP", "conc", 'duration'])
#Loop to extract the data from each file
for i in table_dict:
    #get the values from the config file
    T, date, lipids, septin,duration, GTP, conc, mode = table_dict[i]
    #open file and convert it to a table
    da = pd.read_table(i, decimal=',', sep='\t', lineterminator='\n')
    #Define the mode
    if mode == "a":
        da = da.set_axis(['Time', 'F5', 'D5', 'F7', 'D7', 'F9', 'D9', 'F11', 'D11', 'F13', 'D13',
                          "Meas.Temp.Time", "Tact"], axis=1, inplace=False)
    elif mode =="b":
        da = da.set_axis(['Time', 'F5', 'D5', 'F7', 'D7', 'F9', 'D9', "Meas.Temp.Time", 
                          "Tact"], axis=1, inplace=False) #for file158
    elif mode =="c":
        da = da.set_axis(['Time', 'F5', 'D5', 'F7', 'D7', 'F11', 'D11','F13', 'D13', "Meas.Temp.Time", 
                          "Tact"], axis=1, inplace=False) #for file1712
    #remove unnecessary columns 
    da = da.drop(["Meas.Temp.Time", "Tact"], axis=1)
    #Remove rows with empty data
    da= da.dropna()
    #convert the values in the dataframe into float
    da2=da.astype(float)
    #change time to minutes
    da2.Time=da2.Time/60
    
    #set 0 to start of septin addition:
    #Get the time value nearest to the manually selected start time (of septin addition) and substract that value to all 
    #the time values
    da2.Time=da2.Time-find_nearest(da2.Time,T)
    #Substract the value of frequency shift at which the septin gets into the system in the used overtone 7 to all values 
    #in overtone 7 (same as before but for deltaF instead of time)
    da2.F7=da2.F7-float(da2.F7[da2.Time==0.0])
    #Same but for deltaD
    da2.D7=da2.D7-float(da2.D7[da2.Time==0.0])
    #Set the time to be the index (row name) of the dataframe
    da2=da2.set_index('Time')
    
    #convert f into positve values
    f7 = da2['F7']*-1
    
    #create dataframe with all the new information 
    table = table.append({'F7': f7, 'D7': da2['D7'], 'date': date, 'lipids': lipids, "septin": septin, 
                          "GTP":GTP, "conc": conc, "duration":duration, "soft": da2["D7"]/da2["F7"]*-1}, ignore_index=True)

#Create new (empty) coulms for the interesting parametrs. 
table["maxF"] = ""
table["maxD"] = ""
table["maxafterF"] = ""
table["maxafterD"] = ""
table["maxS"] = ""
table["maxafterS"] = ""
table["soft70"] = ""
table["soft29t"] = ""
#loop to find the values for each experiment
for i in range(table.index[-1]+1):
    table.loc[i,"maxF"] = end_result(table.loc[i,"F7"], table.loc[i,"duration"], 'max')
    table.loc[i,"maxafterF"] = end_result(table.loc[i,"F7"], table.loc[i,"duration"], 'after')
    table.loc[i,"maxD"] = end_result(table.loc[i,"D7"], table.loc[i,"duration"], 'max')
    table.loc[i,"maxafterD"] = end_result(table.loc[i,"soft"], table.loc[i,"duration"], 'after')
    table.loc[i,"maxS"] = table.loc[i,"soft"][(table.loc[i,"soft"].index>=duration-(2/6))&(table.loc[i,"soft"].index<=duration)].mean(axis=0)
    table.loc[i,"maxafterS"] = table.loc[i,"soft"][(table.loc[i,"soft"].index>=table.loc[i,"soft"].index[-1]-(2/6))].mean(axis=0)
    table.loc[i, "soft70"] = table.loc[i,"soft"][(table.loc[i, "F7"] - 70).abs().idxmin()]
    table.loc[i, "soft29t"] = table.loc[i, "soft"][min(list(table.loc[i, "soft"].index), key=lambda x: abs(x - 29))] 
#Get theorical thickness values using the Sauerbrey equation
table['thickness'] = table['maxF']/6.1
# Out:
# C:\Users\gcastrolinares\AppData\Local\Temp\ipykernel_5488\2933542138.py:11: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   da = da.set_axis(['Time', 'F5', 'D5', 'F7', 'D7', 'F9', 'D9', 'F11', 'D11', 'F13', 'D13',
# C:\Users\gcastrolinares\AppData\Local\Temp\ipykernel_5488\2933542138.py:44: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table = table.append({'F7': f7, 'D7': da2['D7'], 'date': date, 'lipids': lipids, "septin": septin,
# C:\Users\gcastrolinares\AppData\Local\Temp\ipykernel_5488\2933542138.py:11: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   da = da.set_axis(['Time', 'F5', 'D5', 'F7', 'D7', 'F9', 'D9', 'F11', 'D11', 'F13', 'D13',
# ...

# %%
groups = table[(table.GTP != "~")&(table.lipids == "mix")&(table.conc == 50)].groupby(['septin', 'GTP'])
group_stats = groups.agg({'thickness': [np.mean, np.std]})
group_stats[('thickness', 'SE')] = group_stats[('thickness', 'std')] / np.sqrt(groups.size())

# %%
group_stats 0.2
# Out:
#             thickness
#                  mean       std        SE
# septin GTP
# hex    +    15.517348  0.542187  0.204927
#        -    13.250756  1.203587  0.491362
# oct    +    13.077358  1.307214  0.494081
#        -    10.331063  1.354077  0.552800
